# %% [markdown]
# # Introduction to Jupyter

# %%
# Type of cell
# 1.Code---write the code(Program)
# 2.Markdown--Heading with Formate
# 3.RAW----Raw text without Formulae

# %%
print("HelloWorld")
# Out:
# HelloWorld

# %% [markdown]
# Example of Markdown

# %% [raw]
# The test will be heading(Esc+M)
#
# ###### Heading
# ##### Heading
# #### Heading
# ### Heading
# ## Heading
# # Heading

# %% [markdown]
# ###### Heading
# ##### Heading
# #### Heading
# ### Heading
# ## Heading
# # Heading

# %% [raw]
# How to write in bold Format
#
# ex: **Hello Guys**

# %% [markdown]
# **Hello Guys**

# %% [raw]
# Text in Italic Format
# ex: *Hello*

# %% [markdown]
# *Hello*

# %% [raw]
# text in Bold+italic
# ***Hello***

# %% [markdown]
# ***Hello***

# %% [raw]
# text in Bold+italic with size
# # ***Hello***

# %% [markdown]
# # ***Hello***

# %% [raw]
# to use bullet points
# - First Day
# - Second day
# - Third day

# %% [markdown]
# - First Day
# - Second day
# - Third day

# %% [raw]
# List in order
# 1. First Day
# 2. Second day
# 3. Third day

# %% [markdown]
# 1. First Day
# 2. Second day
# 3. Third day
