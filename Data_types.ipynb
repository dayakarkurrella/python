# %% [markdown]
# # Data types

# %% [raw]
# Datatype represesnt the type of data, present inside the variable.

# %% [raw]
# In Python weare not required to specify the type explicitly(from outside).

# %% [raw]
# Based on Value provided, type will be assigned automatically.
# i.e., Dynamically types language.

# %% [markdown]
# ## No of datatypes (built in)

# %% [raw]
# Fundamental data types
# ----------------------
# 1. Integer ( int )  -> represents number
# 2. Float  (float)   -> decimal number
# 3. String  (str)    -> character
# 4. Complex   -> real + imag =4+7j
# 5. Boolean  (bool)   -> True/False

# %% [markdown]
# Composite data types
# -------------------
# 1. bytes   -> 0 - 255(256),
# 2. Bytesarray(format will be changed)  ->
# 3. range --> (length of numbers, range)
# 4. list
# 5. tuple
# 6. set
# 7. Frozenset
# 8. Dictionary
# 9. None

# %% [markdown]
# # Examples of Data types

# %% [markdown]
# int data types

# %%
# type() = in built function in python to show data types
a=10
type(a)
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# # we can represent int in multiple format
# 1. Binary(base 2)
# 2. Decimal(base 20)
# 3. Octal(base 8)
# 4. Hexadecimal(base 16)

# %%
binary =0b1111
decimal =1000
octal = 0o456
hexa = 0xA69

# %%
binary
# Out:
# 15

# %%
octal
# Out:
# 302

# %%
hexa
# Out:
# 2665

# %% [markdown]
# ### decimal to all

# %%
a =255

# %%
bin(a),oct(a),hex(a)
# Out:
# ('0b11111111', '0o377', '0xff')

# %% [markdown]
# ### binary to all

# %%
b =0b11111111

# %%
b, oct(b), hex(b)
# Out:
# (255, '0o377', '0xff')

# %% [markdown]
# ### Octal to all

# %%
c = 0o2345

# %%
c, bin(c), hex(c)
# Out:
# (1253, '0b10011100101', '0x4e5')

# %% [markdown]
# ### Hexa to all

# %%
d =0xAB345

# %%
d, bin(d), oct(d)
# Out:
# (701253, '0b10101011001101000101', '0o2531505')

# %% [markdown]
# # Float

# %%
a = 13.34
type(a)
# Out:
# float

# %% [markdown]
# # Complex

# %%
x = 6+4j
type(x)
# Out:
# complex

# %%
x.real
# Out:
# 6.0

# %%
x.imag
# Out:
# 4.0

# %% [markdown]
# # String

# %%
First_name ='Dayakar'
Last_name ='Kurella'

# %%
print(First_name + " " + Last_name)
# Out:
# Dayakar Kurella

# %% [markdown]
# # Writing comments in python

# %% [raw]
# 1. using # you can write comment
# 2. using '' you can write comment
# 3. using "" you can write comment
# 4. using ''' comment ''' for multiline comment

# %% [markdown]
# # Boolean

# %%
a= True
type(a)
# Out:
# bool

# %%
a=20
b=30
a is b
# Out:
# False

# %%
id(a)
# Out:
# 140710070629896

# %%
id(b)
# Out:
# 140710070630216
