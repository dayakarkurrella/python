# %% [raw]
# 1. For running the program we need a software know as compiler or interpreter

# %% [raw]
# 2. For writting the program we need IDE(Pycharm)

# %% [markdown]
# code==>IDE==>Interpret/ompiler==<Byte_code==>PVM==>OUTPUT==>IDE

# %% [markdown]
# Python is a general purpose programming language. (Ex. Solving Problem,Automate)
# Python is a high level programming language.
# Developed by Guido Van Rossam in 1989, working at National institute at Netherland.
# But officially, python was launched on Feb 20 1991.
# This the first programming language for beginners.

# %% [markdown]
# #where is python to download
# #where is the code ofpython

# %% [raw]
# python is opensource

# %% [markdown]
# **How Guido has written the Python**

# %% [markdown]
# 1. Functional programming features from C.
# 2. Object Oriented programming features from C++
# 3. Scripting language features from perl and shell
# 4. Modular programming from Modula-3
# 5. Most of the syntax from C and ABC.

# %% [markdown]
# **Features of Python**

# %% [markdown]
# 1. Python is Simple and Easy
# 2. Freeware and Open Source
# 3. High Level programing language
# 4. Platform independent
# 5. Python is prortable
# 6. Python is dynamically typed language
# 7. Procedure oriented (C) and Object oriented (Java)
# 8. Interpreted lang.
# 9. Extensible lang (with python we can use other prog lang).
# 10. Embedded
# 11. Extensive library

# %% [markdown]
# **Flavours of Python**

# %% [raw]
# C + Python =Cpython
# C + Python =Cython
# Java + python =Jython
# Pyhton + python =PyPython
# Anaconda + python =Anacondapython

# %% [markdown]
# **Version of Python**

# %% [raw]
# Python 1.0 v - Jan 1994
# Python 2.0 v - Jan 2000
# Python 3.0 v - Jan 2008
